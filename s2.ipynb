# %%
from IPython.display import Image
Image("C:/Users/adria/OneDrive/Escritorio/jupy/FOTOS/FOTO_S2.png")

# %% [markdown]
# # **ENCONTRAR LA FUNCION DE TRANSFERENCIA** #
# ## ECUACIONES: ##
#  $ Vi\cdot G_1= (0-V_A)\cdot S \cdot C + (0-V_A) \cdot G_2+(0-V_O) \cdot G_3$
#
#  $ (V_A-0) \cdot G_3=(0-V_B) \cdot S \cdot C $
#
#  $ (V_B-0) \cdot G_4=(0-V_O) \cdot G_4 $
#
# $$
# \begin{cases}
# V_i\,G_1 = V_A\,(sC+G_2)-V_O\,G_3 \\
# V_A\,G_3 = -V_B\,sC \\
# V_B = -V_O
# \end{cases}
# $$
# Desarrollo:
#
# $ V_A \cdot G_3=V_O \cdot S \cdot C  \rightarrow\ V_A= \frac{V_O \cdot S \cdot C}{G_3}$
#
# $ Vi\cdot G_1= \cdot \frac{V_O \cdot S \cdot C}{G_3}(S \cdot C+G_2)-V_O \cdot G_3 = -V_O \cdot (\frac{S^2 \cdot C^2+ S \cdot C \cdot G_2}{G_3}+G_3)= -V_O \cdot (\frac{S^2 \cdot C^2+ S \cdot C \cdot G_2}{G_3^2}) $
#
# $ V_i=-V_O \cdot ( \frac{S^2 \cdot C^2+ S \cdot C \cdot G_2}{G_3^2}) \cdot \frac{1}{G_1}  $
#
# $ \frac{V_O}{V_i}=-\frac{G_3 \dot G_1}{S^2 \cdot C^2+ S\frac{G_2}{c} + G_3^2} $
#
# **Simplifico y obtengo $H(s)$:**
# $$ H(S)=\frac{V_O}{V_i}=-\frac{\frac{G_3 \dot G_1}{C^2}}{S^2+ S \cdot \frac{G_2}{C} + \frac{G_3^2}{C^2}}= \frac{-\frac{G_1}{G_3} \cdot \frac{G_3^2}{C^2} }{S^2+ S \cdot \frac{G_2}{C} + \frac{G_3^2}{C^2}}=-\frac{\frac{1}{R_3 \dot R_1 \dot C^2}}{S^2+ S \cdot \frac{1}{R_2 \dot C} + \frac{1}{R_3^2 \dot C^2}} $$
#
# $$\boxed{H(S)=\frac{V_O}{V_i}=-\frac{G_1}{G_3} \cdot \frac{\frac{G_3^2}{C^2} }{S^2+ S \cdot \frac{G_2}{C} + \frac{G_3^2}{C^2}}} \quad \lor \quad \boxed{H(S)=\frac{V_O}{V_i}=-\frac{R_3}{R_1} \cdot \frac{\frac{1}{C^2\cdot R_3^2} }{S^2+ S \cdot \frac{1}{C\cdot R_2} + \frac{1}{R_3^2\cdot C^2}}}$$
#
# **Pasa bajos de segundo orden**
#
#
# ### Parametros
#
# - En **conductancias**:
#
# $$K = -\frac{G_1}{G_3} \quad , \quad \omega_0 = \frac{G_3}{C} \quad , \quad Q = \frac{G_3}{G_2}$$
#
# - En **resistencias**:
#
# $$K = -\frac{R_3}{R_1} \quad , \quad \omega_0 = \frac{1}{R_3 C} \quad , \quad Q = \frac{R_2}{R_3}$$
#
# ---
#
#
# ### Normalización
#
# Para normalizar:
# - Elijo $G_3$ porque aparece en los tres parametros.
#
# $Z_0= G_3  \rightarrow\ Z_N=\frac{Z}{Z_0}=1 \rightarrow\ G_3=1$
# Por lo tanto:
#
# - La frecuencia angular normalizada es:
#  $\omega_0 = \frac{G_3}{C}  = 1 \rightarrow\  C=1 $  (Esto en realidad es $C=\frac{1}{R_3})$
#
# - La ganancia:
#
#  $K = -G_1=-\frac{1}{R_1}$
#
# - El factor de selectividad:
#
#  $Q = \frac{1}{G_2}=R_2$
#
# **Así, la función de transferencia normalizada se expresa:**
#
# ## $$\boxed{H(s) = \frac{-G_1}{s^2 + s G_2 + 1}= \frac{-\frac{1}{R_1}}{s^2 + s \frac{1}{R_2} + 1}}$$ ##
#
# donde los parámetros libres son $ G_1 $ y $ G_2 $.
#
#
#
# ## **Como podemos obtener un pasa banda utilizando la misma red circuital** ##

# %%
Image("C:/Users/adria/OneDrive/Escritorio/jupy/FOTOS/FOTO_S2_B.jpg")

# %% [markdown]
# ## Sistema de ecuaciones
#
# Partimos del siguiente sistema:
#  $$ \begin{cases}
#  V_i G_1 = (0 - V_o) sC + (0 - V_o) G_2 + (0 - V_a) G_3 \\
#  (V_o - 0) G_3 = (0 - V_b) sC \\
#  (V_b - 0) G_4 = (0 - V_a) G_4 \quad \Rightarrow \quad V_b = -V_a \\
#   \end{cases}
#  $$
#
# Desarrollo:
#
# $(V_o) G_3 = (-(-V_a)) sC=V_a sC$
#
# $V_a = \frac{V_o G_3}{sC}$
#
# $V_i G_1 = -V_o sC - V_o G_2 - V_a G_3$
#
# $V_i G_1 = -V_o sC - V_o G_2 - \left( \frac{V_o G_3}{sC} \right) G_3$
#
# $V_i G_1 = -V_o \left( sC + G_2 + \frac{G_3^2}{sC} \right)$
#
# $V_i G_1 \cdot sC = -V_o \left( (sC + G_2) sC + G_3^2 \right)$
#
# $V_i G_1 sC = -V_o \left( s^2 C^2 + sC G_2 + G_3^2 \right)$
#
# $V_o = -\frac{V_i G_1 sC}{s^2 C^2 + sC G_2 + G_3^2}  \rightarrow\  \frac{V_o}{V_i} = -\frac{G_1 sC}{s^2 C^2 + sC G_2 + G_3^2}$
#
# **Finalmente:**
#
#  $$\boxed{H(s) = -\frac{G_1}{C} \cdot \frac{s}{s^2 + \frac{G_2}{C} s + \frac{G_3^2}{C^2}}=-\frac{1}{R_1 C} \cdot \frac{s}{s^2 + \frac{1}{R_2 C} s + \frac{1}{R_3^2 C^2} }}$$
# **Pasa banda de segundo orden**
#
#
#
# ### Parametros
#
# - $$ K = -\frac{G_1}{C} \quad \rightarrow \quad K = -\frac{1}{R_1 C} $$
# - $$ \omega_0 = \frac{G_3}{C} \quad \rightarrow \quad \omega_0 = \frac{1}{R_3 C} $$
# - $$ Q = \frac{G_3}{G_2} \quad \rightarrow \quad Q = \frac{R_2}{R_3} $$
#
#
#
# ### Normalización (IDEM PASA BAJOS)
#
# Para normalizar:
# - Elijo $G_3$ porque aparece en los tres parametros.
#
# $Z_0= G_3  \rightarrow\ Z_N=\frac{Z}{Z_0}=1 \rightarrow\ G_3=1$
# Por lo tanto:
#
# - La frecuencia angular normalizada es:
#  $\omega_0 = \frac{G_3}{C}  = 1 \rightarrow\  C=1 $  (Esto en realidad es $C=\frac{1}{R_3})$ #
#
# - La ganancia:
#
#  $K = -G_1=-\frac{1}{R_1}$
#
# - El factor de selectividad:
#
#  $Q = \frac{1}{G_2}=R_2$
# Así, la función de transferencia normalizada se expresa:
#
# $$\boxed{H(s) = G_1 \cdot \frac{s}{s^2 + s G_2 + 1} = \frac{1}{R_1} \cdot \frac{s}{s^2 + \frac{s}{R_2} + 1}}$$

# %%
import numpy as np
from scipy.signal import TransferFunction
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay
import matplotlib.pyplot as plt

# %% [markdown]
# ## $$\boxed{H_{LP}(s) = \frac{-G_1}{s^2 + s G_2 + 1}= \frac{-\frac{1}{R_1}}{s^2 + s \frac{1}{R_2} + 1}}$$ ##

# %%
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay
# PASA BAJOS
# Parámetros normalizados 
R1 = 2  # Valor arbitrario
R2 = 100  # Valor arbitrario
R3 = 1    # ohm (por normalización)

K = -R3 / R1
Q = R2 / R3
w0 = 1  # normalizado

# Función de transferencia normalizada
num = [0,0, K * (w0**2)]            # numerador: K * w0**2 * s
den = [1, w0/Q, w0**2]          # denominador: s^2 + (w0/Q) * s + w0^2

H = TransferFunction(num, den)

# Plots
bodePlot(H, fig_id=1, filter_description='H(s) normalizado')
pzmap(H, fig_id=2, filter_description='H(s) normalizado')
GroupDelay(H, fig_id=3, filter_description='H(s) normalizado')

plt.show()
# Out:
# C:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\_ltisys.py:599: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   self.num, self.den = normalize(*system)

# %% [markdown]
# ## $$\boxed{H_{BP}(s) = G_1 \cdot \frac{s}{s^2 + s G_2 + 1} = \frac{1}{R_1} \cdot \frac{s}{s^2 + \frac{s}{R_2} + 1}}$$

# %%
## PASA BANDA
# Parámetros normalizados 
R1 = 0.10  # Valor arbitrario
#R2 = 5  # Valor arbitrario
R3 = 1    # ohm (por normalización)
C=1      # faradios (por normalizacion)

K = -1 / R1*C
Q = R2 / R3
# w0 = 1   normalizado

# Función de transferencia normalizada
num = [0, K, 0]
den = [1, 1/Q, 1]

H = TransferFunction(num, den)

# Plots
bodePlot(H, fig_id=1, filter_description='H(s) normalizado')
pzmap(H, fig_id=2, filter_description='H(s) normalizado')
GroupDelay(H, fig_id=3, filter_description='H(s) normalizado')

plt.show()
# Out:
# C:\Users\adria\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\signal\_ltisys.py:599: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   self.num, self.den = normalize(*system)

# %%
from IPython.display import Image
print("PASA BAJOS DE SEGUNDO ORDEN")
Image("C:/Users/adria/OneDrive/Escritorio/jupy/FOTOS/FOTO_S2_PBAJOS.png")
# Out:
# PASA BAJOS DE SEGUNDO ORDEN

# %%
from IPython.display import Image
print("PASA BANDA DE SEGUNDO ORDEN")
Image("C:/Users/adria/OneDrive/Escritorio/jupy/FOTOS/FOTO_S2_PBANDA.png")
# Out:
# PASA BANDA DE SEGUNDO ORDEN

# %% [markdown]
# # Filtro Chebyshev
#
# ---
#
# | Parámetro | Valor |
# |----------|----------|
# | $\alpha_{\max}$ | $0.4$ dB |
# | $\alpha_{\min}$ | $48$ dB |
# | $f_p$ | $3200$ Hz |
# | $f_s$ | $9600$ Hz |
#
# ---
#
# **Frecuencia normalizada:**
#
# $$
# \Omega_s=\frac{f_s}{f_p} \quad \Rightarrow \quad \boxed{\Omega_s=3}
# $$
#
#
# **Cálculo del ripple $\varepsilon$**
#
#
# $$
# \alpha_{\max}=10\log(1+\varepsilon^2) \quad \Rightarrow \quad \varepsilon^2=10^{\frac{\alpha_{\max}}{10}}-1
# $$
#
# $$
# \varepsilon=
# \sqrt{10^{\frac{0.4}{10}}-1}
# \approx0.31
# $$
#
# $$
# \boxed{\varepsilon\approx0.31} \quad\land\quad \boxed{\varepsilon^2\approx0.096}
# $$
#
#
# **Cálculo del orden $n$ Para un filtro Chebyshev:**
#
# $$
# n\ge
# \frac
# {\cosh^{-1}
# \left(
# \sqrt{
# \frac
# {10^{\frac{\alpha_{\min}}{10}}-1}
# {10^{\frac{\alpha_{\max}}{10}}-1}
# }
# \right)}
# {\cosh^{-1}(\Omega_s)}
# $$
#
#
# $$
# n\ge
# \frac
# {\cosh^{-1}
# \left(
# \sqrt{
# \frac
# {10^{\frac{48}{10}}-1}
# {10^{\frac{0.4}{10}}-1}
# }
# \right)}
# {\cosh^{-1}(3)}
# \approx4.19
# $$
#
#
# $$
# n\ge4.19 \quad \Rightarrow \quad \boxed{n=5}
# $$
#
#
# ## Forma general de la función de transferencia
#
# Para un filtro de orden cinco:
#
# $$
# T(s)=
# \frac{K}
# {(s-s_1)(s-s_2)(s-s_3)(s-s_4)(s-s_5)}
# $$
#
# Agrupando polos conjugados:
#
# $$
# T(s)=
# \frac{K}
# {
# (s^2+\frac{\omega_{01}}{Q_1}s+\omega_{01}^2)
# (s^2+\frac{\omega_{02}}{Q_2}s+\omega_{02}^2)
# (s+\omega_{03})
# }
# $$
#
# Por lo tanto, el filtro queda compuesto por:
#
# - Dos celdas de segundo orden.
# - Una celda RC de primer orden.
#
# conectadas en cascada.
#
# **Ubicación de polos**
#
# Calculamos primero la apertura de la elipse:
#
# $$
# a=\frac{1}{n}\sinh^{-1}\left(\frac{1}{\varepsilon}\right)=\frac{1}{5}\sinh^{-1}\left(\frac{1}{0.309}\right)\approx0.378
# $$
#
# $$
# \boxed{a\approx0.378}
# $$
#
# Los ángulos de los polos son:
#
# $$
# \theta_k=
# \frac{(2k-1)\pi}{2n}
# $$
#
# Por lo tanto:
#
# $$
# \theta_1=\frac{\pi}{10} \quad ; \quad \theta_2=\frac{3\pi}{10} \quad ; \quad \theta_3=\frac{5\pi}{10} \quad ; \quad \theta_4=\frac{7\pi}{10} \quad ; \quad \theta_5=\frac{9\pi}{10}
# $$
#
#
# **Coordenadas de los polos:**
#
# Sabemos que:
#
# $$
# s_k=\sigma_k+j\omega_k
# $$
#
# con
#
# $$
# \sigma_k=-\sinh(a)\sin(\theta_k)
# $$
#
# $$
# \omega_k=\cosh(a)\cos(\theta_k)
# $$
#
# Obteniendo:
#
# $$
# s_1=-0.1193+j1.0195
# $$
#
# $$
# s_2=-0.3124+j0.6301
# $$
#
# $$
# s_3=-0.3862
# $$
#
# $$
# s_4=-0.3124-j0.6301
# $$
#
# $$
# s_5=-0.1193-j1.0195
# $$
#
# **Obtención de $\omega_0$ y $Q$**
#
# Sabemos que dos polos conjugados cumplen:
#
# $$
# (s-p)(s-p^*)=(s-(\sigma+j\omega))(s-(\sigma-j\omega))
# $$
#
# Desarrollando:
#
# $$
# (s-p)(s-p^*)=s^2-2\sigma s+(\sigma^2+\omega^2)
# $$
#
# Como los polos tienen parte real negativa, podemos escribir:
#
# $$
# (s-p)(s-p^*)=s^2+2|\sigma|s+(\sigma^2+\omega^2)
# $$
#
# Comparando con la forma canónica:
#
# $$
# s^2+\frac{\omega_0}{Q}s+\omega_0^2 \quad \Rightarrow  \quad \begin{cases} \omega_0^2=\sigma^2+\omega^2 \\ \frac{\omega_0}{Q}=2|\sigma| \\ \end{cases}
# $$
#
# **Para $s_1$ y $s_5$**
#
# Tomando:
#
# $$
# s_1=-0.1193+j1.0195
# $$
#
# $$
# s_5=-0.1193-j1.0195
# $$
#
# Resulta:
#
# $$
# (s-s_1)(s-s_5)=s^2+s(0.1193+0.1193)+(0.1193)^2+(1.0195)^2
# $$
#
# $$
# s^2+0.2386s+1.0536 = s^2+\frac{\omega_{01}}{Q_1}s+\omega_{01}^2
# $$
#
# obtenemos:
#
# $$
# \omega_{01}^2=1.0536  \quad \Rightarrow  \quad  \omega_{01}=\sqrt{1.0536} \quad \Rightarrow  \quad \boxed{\omega_{01}=1.0264}
# $$
#
# Además:
#
# $$
# \frac{\omega_{01}}{Q_1}=0.2386 \quad \Rightarrow  \quad Q_1=\frac{\omega_{01}}{0.2386} \quad \Rightarrow  \quad \boxed{Q_1=4.30}
# $$
#
#
# **Para $s_2$ y $s_4$**
#
# Tomando:
#
# $$
# s_2=-0.3124+j0.6301
# $$
#
# $$
# s_4=-0.3124-j0.6301
# $$
#
# Resulta:
#
# $$
# (s-s_2)(s-s_4)=s^2+s(0.3124+0.3124)+(0.3124)^2+(0.6301)^2
# $$
#
# $$
# s^2+0.6248s+0.4946 = s^2+\frac{\omega_{02}}{Q_2}s+\omega_{02}^2
# $$
#
# obtenemos:
#
# $$
# \omega_{02}^2=0.4946 \quad \Rightarrow \quad \omega_{02}=\sqrt{0.4946} \quad \Rightarrow  \quad \boxed{\omega_{02}=0.7033}
# $$
#
# Además:
#
# $$
# \frac{\omega_{02}}{Q_2}=0.6248 \quad \Rightarrow \quad Q_2=\frac{\omega_{02}}{0.6248} \quad \Rightarrow \quad \boxed{Q_2=1.1256}
# $$
#
# **Para el polo real $s_3$**
#
# Tomando:
#
# $$
# s_3=-0.3862
# $$
#
# Resulta:
#
# $$
# (s-s_3)=s+0.3862 = s+\omega_{03}
# $$
#
# obtenemos:
#
# $$
# \boxed{\omega_{03}=0.3862}
# $$
#
#
# ## Función de transferencia obtenida
#
# Con los valores calculados:
#
# $$ \begin{cases}
# \omega_{01}=1.0264 \quad\land\quad Q_1=4.30 \\
# \omega_{02}=0.7033 \quad\land\quad Q_2=1.1256 \\
# \omega_{03}=0.3862
# \end{cases}
# $$
#
#
# Resulta:
#
# $$
# T(s)=\frac{K_1}{s^2+s\frac{1.0264}{4.30}+(1.0264)^2}\cdot\frac{K_2}{s^2+s\frac{0.7033}{1.1256}+(0.7033)^2}\cdot\frac{K_3}{s+0.3862}
# $$
#
# Operando:
#
# $$
# \boxed{T(s)=\frac{K_1}{s^2+0.2387s+1.0535}\cdot\frac{K_2}{s^2+0.6248s+0.4946}\cdot\frac{K_3}{s+0.3862}}
# $$
#
#
# # Celda de primer orden
#
# La forma general de un filtro RC pasabajos es:
#
# $$
# T(s)=\frac{\frac{1}{RC}}{s+\frac{1}{RC}} = \frac{\omega_0}{s+\omega_0} = \frac{\omega_{03}}{s+\omega_{03}}
# $$
#
# Tomando:
#
# $$
# \text{Sí }\quad \omega_{03}=\frac{1}{RC}  \quad \land \quad R=10k\Omega \quad \Rightarrow \quad \begin{cases}
# C=\frac{1}{R\omega_{03}} \quad \Rightarrow \quad \boxed{C\approx260\mu F} \\
# \end{cases}
# $$
#
# # Implementación Ackemberg-Mossberg
#
# La forma general de una celda Ackemberg-Mossberg pasabajos es:
#
# $$
# T(s)=\frac{-R_3}{R_1}\cdot\frac{\frac{1}{C^2R_3^2}}{s^2+s\frac{1}{C R_2}+\frac{1}{C^2R_3^2}}=K\cdot\frac{\omega_0}{s^2+s\frac{\omega_0}{Q}+\omega_0^2}
# $$
#
# **Obtención de $\omega_{01}$ y $Q_1$:**
#
# $$
# \text{Sí }\quad R_1=R_3=100k\Omega \quad \Rightarrow \quad \begin{cases}
# \frac{1}{C_1^2R_3^2}=\omega_{01}^2=1.0535 \quad \Rightarrow \quad C_1=\sqrt{\frac{1}{R_3^2\cdot1.0535}} \quad \Rightarrow \quad \boxed{C_1\approx10\mu F} \\
# \frac{1}{C_1R_2}=\frac{\omega_{01}}{Q_1}=0.2387 \quad \Rightarrow \quad R_2=\frac{1}{0.2387\cdot C_1} \quad \Rightarrow \quad \boxed{R_2\approx430k\Omega}
# \end{cases}
# $$
#
#
# La ganancia resulta:
#
# $$
# K_1=-\frac{R_3}{R_1}\omega_{01}^2 \quad \Rightarrow \quad \boxed{K_1=-1.0535}
# $$
#
# **Obtención de $\omega_{02}$ y $Q_2$**
#
# $$
# \text {Sí } \quad R_1=R_3=10k \quad \Rightarrow \quad \begin{cases}
# \frac{1}{C_2^2R_3^2}=\omega_{02}^2=0.4946 \quad \Rightarrow \quad C_2=\sqrt{\frac{1}{R_3^2\cdot0.4946}} \quad \Rightarrow \quad \boxed{C_2\approx142.2\mu F} \\
# \frac{1}{C_2R_2}=\frac{\omega_{02}}{Q_2}=0.6248 \quad \Rightarrow \quad R_2=\frac{1}{C_2\cdot0.6248} \quad \Rightarrow \quad \boxed{R_2\approx11,256\text{K}\Omega}
# \end{cases}
# $$
#
# La ganancia resulta:
#
# $$
# K_2=-\frac{R_3}{R_1}\omega_{02}^2 \quad \Rightarrow \quad \boxed{K_2=-0.4946}
# $$
#
#
# ## Función de transferencia final
#
# $$
# \boxed{T(s)=\frac{-1.0535}{s^2+0.2387s+1.0535}\cdot\frac{-0.4946}{s^2+0.6248s+0.4946}\cdot\frac{0.3862}{s+0.3862}}
# $$
#
# ---
#
# ## Valores finales de los componentes
# $$
# \omega_{03} \quad  \begin{cases}
# R=10k\Omega\\
# C_1=260\mu F\\
# \end{cases}
# $$
#
# $$
# \omega_{01} \quad \text{y} \quad Q_1 \begin{cases}
# R_1=R_3=100k\Omega\\
# R_2=430k\Omega\\
# C_1=10\mu F\\
# \end{cases}
# $$
#
# $$
# \omega_{02} \quad \text{y} \quad Q_2 \begin{cases}
# R_1=R_3=10k\Omega\\
# R_2=11,256k\Omega\\
# C_1=142,2\mu F\\
# \end{cases}
# $$
